# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedebeed555/LinearRegression/blob/main/11Aug2025LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
(X,y)=make_regression(n_samples=100,n_features=1,noise=10,random_state=42)

# %%
model=LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X)

# %%
print(mean_squared_error(y,y_pred))
print(r2_score(y,y_pred))
# Out:
# 78.054250421239
# 0.9538252459635717

# %%
plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
plt.show()
