# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedebeed555/LinearRegression/blob/main/10aug2025LinearRegressionHandOn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression

# %%
# make the regression data

(X,y)=make_regression(n_samples=100,n_features=1,noise=10,random_state=42)

# %%
#fit the data and train the model
model=LinearRegression()
model.fit(X,y,)
#predict
y_pred=model.predict(X)

# %%
#plot the actual and predicted data

plt.scatter(X,y,color='red')
plt.plot(X,y_pred,color='blue')
plt.show()
